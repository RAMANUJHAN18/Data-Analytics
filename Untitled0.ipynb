# %%
print("hello")
# Out:
# hello

# %%
x=5
y="sarathi"
print(x)
print(y)
# Out:
# 5
# sarathi

# %%
X=4
x="Ramji"
X=6
print(x)
# Out:
# Ramji

# %%
age=22
name="kishore"
print(name,age)
# Out:
# kishore 22

# %%
+
